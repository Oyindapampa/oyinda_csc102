# %% [markdown]
# ### project 4
#
# ## pseudoocode for project 4
# start
#
#
# input a = integer
#
# input b = integer
#
# input c =  integer
#
#
# d = a and b and c
#
#
# add a + b + c, sutract from maximum value in d and minimum value in d = e
#
#
# print max value (in d)
#
# print min value (in d)
#
# print middle value(e)
#
#
# end

# %%
a= int(input("a= "))
b= int(input('b= '))
c= int(input("c= "))
d = (a,b,c)
e = (a+b+c)-max(d)-min(d)
print("maximum = ",  max(d))
print ("minimum = ", min(d))
print("middle = ", (e))
# Out:
# a= 8
# b= 9
# c= 7
# maximum =  9
# minimum =  7
# middle =  8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### PROJECT 5
#
# ### Pseudocode for project 5
# start
#
# input number = a
#
# while a > 0
#
# sum the cubes of all positive integers less than (a) = total
#
# print (total)
#
# end

# %%
a=int(input("Input number:"))
a -= 1
total = 0
while a > 0:
    total += a ** 3
    a -= 1
print("Sum of cubes smaller than the specified number: ",total)
# Out:
# Input number:4
# Sum of cubes smaller than the specified number:  36

# %% [markdown]
# ![image.png](attachment:image.png)
