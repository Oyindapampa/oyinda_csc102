# %% [markdown]
# ## OYINDAMOLA APAMPA
#
# ## MATRIC NO : 21120612450
#
# ## oyindamola.apampa@pau.edu.ng
#
#
#
# #### Class Projects
#
# ###### PROJECT I
#
# ##### PSEUDOCODE FOR PROJECT I
# #### x = (input x)
# #### y = (x + 17)
#
# #### if y > 17
# ####         d = double the difference of x and 17
# ####         f = absolute value of d
# #### print f

# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)

# %%
x= int(input("type in number" ))
print(x)
y = x+17
print (y)
if y > 17:
    d = (2 * (x - 17))
    f = abs(d)
    print(f)
# Out:
# type in number9
# 9
# 26
# 16

# %% [markdown]
# ###### Pseudocode for Project II
# ##### a = (input a)
# ##### b = (input b)
# ##### c = (input c)
#
# ##### z = sum of a , b and c
#
# ##### if a = b = c
#
# ##### print z tripled
#
# ##### else
#
# ##### print z

# %% [markdown]
# ![Picture2.png](attachment:Picture2.png)

# %%
a = int(input("a = " ))
b = int(input("b = " ))
c = int(input("c = " ))

z = a + b + c

if a == b and a == c and b == c:
    print (3 * z)
else:
        print(z)
# Out:
# a = 1
# b = 2
# c = 3
# 6

# %% [markdown]
# ### Pseudocode for project III
#
# ##### d = (input d)
# ##### e = (input e)
# ##### f = sum of d and e
# ##### g = difference between d and e
# ##### if d = e or f = 5 or g = 5
# ##### print true
# ##### if else print false

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
d = int(input("d = "))
e = int(input("e = "))
f = d + e
g = d - e
print (f)
print (g)

if d == e or f == 5 or g == 5:
    print('true')
else:
        print ("false")
# Out:
# d = 9
# e = 4
# 13
# 5
# true
